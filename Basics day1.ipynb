# %% [markdown]
# #### print() function

# %%
print(help(print))
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
#
# None

# %%
print("hello world") # prints string
# Out:
# hello world

# %%
print(*"hello world") # here * denotes variable length argument
# Out:
# h e l l o   w o r l d

# %%
print("hello "," world")  # we can give any number of values in print function to stream
# Out:
# hello   world

# %%
print(*"sparsh",sep="\t")
# Out:
# s	p	a	r	s	h

# %%
print(*"hello",end="\n")  #use of end and sep
print(*"sparsh",sep="\t")
# Out:
# h e l l o
# s	p	a	r	s	h

# %%
type(print())  # print function is none type
# Out:
# NoneType

# %% [markdown]
# ##### input() function

# %% [markdown]
# ###### input() is a function which is used to take entries from the user
# # it enable us to provide data required by the program
# # input() function return string
# # we can typecast output generated by the input() function to desired datatype.

# %%
input()
# Out:
# sparsh
# 'sparsh'

# %%
x=input("Enter your name :")
print(type(x))
print(x)
# Out:
# Enter your name :sparsh
# <class 'str'>
# sparsh

# %%
x=input("x:")
y=input("y:")
print(x+y)
##here x and y are strings thats why string concatenation takes place.
# Out:
# x:3
# y:4
# 34

# %%
x=int(input("x:"))
y=int(input("y:"))# for adding two numbers we need to typecast string into int,float.

print(x+y)
# Out:
# x:3
# y:4
# 7

# %%
# we can aslo take two input seperated by integer using input() function.
x,y=map(int,(input("enter two number seperated by space").split()))
print(x)
print(y)

# split() function actually return list whose members are produced by spliting string from where we encounter space.
# map (datatype,iterable)  return map object   maps each value of iterable to specified datatype one by one.
# Out:
# enter two number seperated by space12 23
# 12
# 23

# %%
x=' i am brave'
x.split()#--->list
# Out:
# ['i', 'am', 'brave']

# %%
x=float(input())
print(type(x))
# Out:
# 4.5
# <class 'float'>

# %%
x=eval(input())  # eval function itself identifies what the class of given value.   
print(type(x))
# Out:
# 5
# <class 'int'>

# %%
x=eval(input())
print(type(x))
# Out:
# 2.3
# <class 'float'>

# %%
x=eval(input())
print(type(x))
# Out:
# 'sparsh'
# <class 'str'>

# %%
x=eval(input())
print(type(x))
# Out:
# [1,2,3,4]
# <class 'list'>

# %%
x=eval(input())
print(type(x))
# Out:
# (1,2,3,4,)
# <class 'tuple'>

# %%
x=eval(input())
print(type(x))
# Out:
# {1:'sparsh',2:'jain'}
# <class 'dict'>

# %%
x=eval(input())
print(type(x))
# Out:
# {1,2,3}
# <class 'set'>

# %% [markdown]
# ###### basic functions used in python

# %%
x=bin(12)  #return binary number
x
# Out:
# '0b1100'

# %%
x=123
x.bit_length()  # returns amount of space used by integer in memory
# Out:
# 7

# %%
len('sparsh') # len(iterable)  returns length of iterable
# Out:
# 6

# %%
type(range(1,5))  # returns return object and provides value  one by one from specified range
#range(start,stop,step)
# Out:
# range

# %%
for i in range(1,5):
    print(i,end="\n")
# Out:
# 1
# 2
# 3
# 4

# %%
oct(123)  #return octal number
# Out:
# '0o173'

# %%
hex(123)  # return hexadecimal number
# Out:
# '0x7b'

# %%
ord('A')  # returns ASCII value of characters
# Out:
# 65

# %%
chr(65)  # return character associated to specified ASCII value
# Out:
# 'A'

# %% [markdown]
# ###### complex numbers

# %%
#complex numbers are those numbers which are wriiten in form of "real + img"
x=12+13j
type(x)
# Out:
# complex

# %%
y=13+10j
x+y  # addition of two complex numbers
# Out:
# (25+23j)

# %%
x*y  # multiplication of two comlplex numbers
# Out:
# (26+289j)

# %%
x-y  # substraction of two complex numbers
# Out:
# (-1+3j)

# %%
x/y  # division of two complex numbers
# Out:
# (1.0631970260223047+0.18215613382899623j)
