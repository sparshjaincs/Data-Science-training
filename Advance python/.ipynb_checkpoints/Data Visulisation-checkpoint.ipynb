# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
print(dir(plt))
# Out:
# ['Annotation', 'Arrow', 'Artist', 'AutoLocator', 'Axes', 'Button', 'Circle', 'Figure', 'FigureCanvasBase', 'FixedFormatter', 'FixedLocator', 'FormatStrFormatter', 'Formatter', 'FuncFormatter', 'GridSpec', 'IndexLocator', 'Line2D', 'LinearLocator', 'Locator', 'LogFormatter', 'LogFormatterExponent', 'LogFormatterMathtext', 'LogLocator', 'MaxNLocator', 'MultipleLocator', 'Normalize', 'NullFormatter', 'NullLocator', 'Number', 'PolarAxes', 'Polygon', 'Rectangle', 'ScalarFormatter', 'Slider', 'Subplot', 'SubplotTool', 'Text', 'TickHelper', 'Widget', '_INSTALL_FIG_OBSERVER', '_IP_REGISTERED', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_auto_draw_if_interactive', '_autogen_docstring', '_backend_mod', '_get_running_interactive_framework', '_interactive_bk', '_log', '_pylab_helpers', '_setp', '_setup_pyplot_info_docstrings', '_show', '_string_to_bool', 'acorr', 'angle_spectrum', 'annotate', 'arrow', 'autoscale', 'autumn', 'axes', 
# ...

# %% [markdown]
# # line plot

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10,4),facecolor='Gray')
a=np.random.randint(1,20,30)

plt.plot(a,"ro--",lw=2,label="Random Plot")
plt.title("RANDOM PLOT",fontsize=20)
plt.xlabel("X-AXIS",fontsize=20)
plt.ylabel("Y-AXIS",fontsize=20)
plt.xticks(np.arange(0,30))
plt.yticks(np.arange(0,20))
plt.legend()
plt.savefig("randomplot.jpeg")
plt.show()

# %%
plt.figure(figsize=(10,6),facecolor="gray")

angle=np.arange(0,361,15)
rad=np.deg2rad(angle)
sin=np.sin(rad)
cos=np.cos(rad)
tan=np.tan(rad)
plt.plot(angle,sin,"ro--",lw=2,label="SIN$\Theta$",alpha=0.9)
plt.plot(angle,cos,"go--",lw=2,label="COS$\Theta$",alpha=0.9)
plt.xlabel("ANGLE",fontsize=20)
plt.ylabel("RADIAN",fontsize=20)
plt.xticks(np.arange(0,361,30))
#plt.yticks(rad)
plt.title("SIN VS COS",fontsize=20)
plt.legend(fontsize=15)
plt.savefig("SINVSCOS.png")
#plt.plot(angle,tan)
plt.show()

# %%
np.inf  # infinity
# Out:
# inf

# %%
a1=np.arange(0,76,15)
a2=np.arange(100,260,15)
a3=np.arange(280,350,15)
deg=np.append(a1,a2)
deg=np.append(deg,a3)
deg
# Out:
# array([  0,  15,  30,  45,  60,  75, 100, 115, 130, 145, 160, 175, 190,
#        205, 220, 235, 250, 280, 295, 310, 325, 340])

# %%
rad=np.deg2rad(deg)
tan=np.tan(rad)

# %%
plt.figure(figsize=(10,6),facecolor="gray")
plt.plot(deg,tan,"bo--",lw=2,label="TAN$\Theta$",alpha=0.9)
plt.plot(angle,sin,"ro--",lw=2,label="SIN$\Theta$",alpha=0.9)
plt.plot(angle,cos,"go--",lw=2,label="COS$\Theta$",alpha=0.9)
plt.xlabel("ANGLE",fontsize=20)
plt.ylabel("RADIAN",fontsize=20)
plt.xticks(np.arange(0,361,30))

plt.title("SIN VS COS VS TAN",fontsize=20)
plt.legend(fontsize=15)
plt.grid(color="Gray")
plt.savefig("SINVSCOSVSTAN.png")

plt.show()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,6),facecolor="Gray")
x=np.linspace(-5,5,500)
ax.plot(x,x**2,"r--",lw=3,label="$X^2$")
ax.plot(x,x**3,"g--",lw=3,label="$X^3$")
ax.set_facecolor("#123456")
ax.set_xlabel("X-Axis",fontsize=20)
ax.set_ylabel("Y-Axis",fontsize=20)
ax.set_xticks(np.arange(-10,10,2))
ax.set_yticks(np.arange(-120,120,20))
ax.legend(fontsize=20)
ax.set_title("X^2 VS X^3",fontsize=20)
ax.set_xlim([-20,20])
ax.set_ylim([-150,150])
plt.grid()
plt.show()

# %%
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(8,3))
#print(ax)
fig.set_facecolor("#abcdef")
ax[2].plot(x,x**4)
ax[1].plot(x,x**3)
ax[0].plot(x,x**2)
plt.show()

# %%
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(8,3))
power = 2
fig.set_facecolor("#abcdef")
title =  [ "$X^2$","$X^3$","$X^4$"]
ax[0].set_ylabel("Y_axis")
for axes in ax : 
    axes.plot(x,x**power)
    axes.spines['right'].set_visible(False)
    axes.spines['top'].set_visible(False)
    axes.set_facecolor("#abcdef")
    axes.set_title(title[power-2])
    axes.set_xlabel("X_axis")
    power += 1
plt.show()

# %%
fig,ax = plt.subplots(nrows=3,ncols=2,sharex=True,sharey=True)
x = np.linspace(-5,5,100)
power = 2
for axes in ax :  
        axes[0].plot(x,x**power)
        axes[1].plot(x,(x+5)**power)
        power += 1
        axes[0].spines['right'].set_visible(False)
        axes[1].spines['right'].set_visible(False)
        axes[0].spines['top'].set_visible(False)
        axes[1].spines['top'].set_visible(False)
        break

# %% [markdown]
# # line plot

# %%
# bydefault plot 
# .plot() is a basic command which will takes arbitary number of arguments to plot a vs y we can use this command as 
plt.plot([1,2,3,4],[5,6,7,8],animated=True)
plt.show()

# %%
x=np.arange(-10,10,2)
x
# Out:
# array([-10,  -8,  -6,  -4,  -2,   0,   2,   4,   6,   8])

# %%
y=np.random.randint(1,10,10)
y
# Out:
# array([2, 7, 9, 5, 7, 4, 6, 6, 7, 9])

# %%
plt.plot(x,y,"r*:",x-10,y+10,"g^--")# .plot() can takes arbitary number of argumnets
plt.show()

# %%
x=np.linspace(-1,1,100)

# %%
plt.figure(facecolor="Gray",figsize=(10,4))
plt.plot(x,x,"ro--",lw=2,alpha=.4,label="X")
plt.plot(x,x**2,"g*:",lw=2,label="$X^2$")
plt.plot(x,x**3,"b^-",lw=2,label="$X^3$")
plt.xlabel("X-AXIS",fontsize=20)
plt.ylabel("Y-AXIS",fontsize=20)
plt.legend(fontsize=20)
plt.title("X VS $X^2$ VS $X^3$",fontsize=20)
plt.grid()
plt.show()

# %%
plt.plot(x,np.log(x),'r')
plt.plot(x,np.log2(x),'g')
plt.plot(x,np.log10(x),'b')
plt.plot(x,np.exp(x),'m')
plt.show()
# Out:
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log2
#
# c:\users\sparsh jain\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig,ax=plt.subplots(nrows=2,ncols=3,figsize=(10,6),facecolor="Gray",sharex=True,sharey=True)
for i in range(2):
    for j in range(3):
        ax[i][j].plot(x,x**(i+j))
plt.show()

# %%
fig = plt.figure(figsize=(10,4),facecolor="#cccccc")
ax1 = fig.add_axes([0,0,1,1])
ax1.set_facecolor("red")
ax1.set_title("$X^3$")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")
ax1.plot(x,x**3)
ax2 = fig.add_axes([0.05,0.533,.3,.4])
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.plot(x,x**2)
ax2.set_title("$X^2$")
ax2.set_xlabel("X-axis")
ax2.set_ylabel("Y-axis")
ax3 = fig.add_axes([0.7,0.1,.3,.4])
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.plot(x,x**4)
ax3.set_title("$X^4$")
ax3.set_xlabel("X-axis")
ax3.set_ylabel("Y-axis")
plt.show()

# %%
####  To show relationship we plot scatter graph

# %%
x=np.random.randint(1,100,150)
y=np.random.randint(1,100,150)
plt.scatter(x,y,color="blue",alpha=.5,lw=2)
plt.show()

# %%
height = np.random.normal(5.5,1.5,100)
weight = height*20.5 + np.random.random(100)*60
plt.scatter(height,weight)
plt.xlabel("HEIGHT")
plt.ylabel("WEIGHT")
plt.show()

# %% [markdown]
# # TO SEE DISTRIBUTION OF DATA

# %%
# HISTOGRAM

# %%
plt.hist(height,edgecolor='black',bins=30)
plt.show()

# %%
plt.hist(weight,edgecolor='black',bins=30)
plt.axis([0,300,0,15])  #plt.axis([xmin,xmax,ymin,ymax])
plt.plot([150,150],[0,10],'r',lw=3)
plt.plot([weight.mean(),weight.mean()],[0,10],'g',lw=3)
plt.show()

# %%
plt.boxplot(weight)
plt.show()

# %%
dta={
    'a':np.random.randint(1,10,20),
    'b':np.arange(1,20,4),
    'c':np.random.randint(1,10,20)
}
plt.scatter('a','c',c='c',s='a',data=dta,lw=10)
plt.plot()
# Out:
# []

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
# bar chart
label=['india','brazil','pakistan','south africa','australia']
freq=[260,290,220,180,230]
plt.bar(label,freq,color=['r','b','g','y','m'])
plt.show()

# %%
# bar chart
label=['india','brazil','pakistan','south africa','australia']
freq=[260,290,220,180,230]
plt.barh(label,freq,color=['r','b','g','y','m'])
plt.show()

# %%
# bar chart
label=['india','brazil','pakistan','south africa','australia']
freq=[260,290,220,180,230]
plt.bar(label,freq,color=['r','b','g','y','m'])
plt.xticks(rotation=90)
plt.show()

# %%
# bar chart 
labels = [ "India", "Aus", "NZ", "PAK","AFG"]
freq = [ 260, 290, 220, 190, 60 ]
color = [ 'b','y','k','g','m'] 
e = [ 0.2, 0, 0, 0.1, 0]
plt.pie(x=freq,labels=labels,colors=color,shadow=True,
       autopct="%.2f",counterclock=False,
       startangle=90,explode=e)
plt.show()

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
ax=plt.subplot(projection='3d')
x=np.random.randint(1,20,30)
y=np.random.randint(1,20,30)
z=np.random.randint(1,20,30)
ax.scatter(x,y,z)
ax.set_xticks(np.arange(0,20,2))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# live plots 
import psutil
import time
for var in range(10): 
    print(psutil.cpu_percent(),flush=True)
    time.sleep(2)
# Out:
# 0.0
# 39.5
# 42.3
# 46.1
# 20.7
# 51.7
# 25.4
# 27.1
# 45.6
# 31.9

# %%
import matplotlib.pyplot as plt
from psutil import cpu_percent as cpu 
from time import sleep
from matplotlib.animation import FuncAnimation
#plt.rcParams['animation.html'] = 'jshtml'
# %matplotlib notebook
x = list(range(1,51))
y = []
for var in range(50): 
    y.append(cpu())
    sleep(.2)  
fig,ax = plt.subplots()
ax.plot(x,y,'ro--')
def change(interval):
    x.pop(0)
    y.pop(0)
    x.append(x[-1]+1)
    y.append(cpu())
    ax.clear()
    ax.plot(x,y,'ro--')
    sleep(0.2)
ani = FuncAnimation(fig,change,2000)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # seaborn for better looking pots

# %%
# %matplotlib inline
x=np.random.randint(1,10,12)
y=np.random.randint(1,10,12)
fig,ax=plt.subplots(figsize=(10,4),facecolor="Gray")
sns.lineplot(x,y,color='red',ls="-",marker="*",ax=ax)
plt.grid()

plt.show()

# %%
x = np.random.normal(5.5,1.5,1000)
y = x*np.random.random(1000) + np.random.random(1000)*5
sns.scatterplot(x,y,hue=np.random.randint(1,10,1000))
plt.show()

# %%
sns.distplot(y,kde=False,hist_kws={'edgecolor':'black'},color="red")
plt.show()

# %%
sns .jointplot(x,y,edgecolor="black")
plt.show()

# %%
sns.boxplot(y)
plt.show()

# %%
sns.violinplot(y)
plt.show()

# %%
sns.swarmplot(y)
plt.show()

# %%
sns.stripplot(y)
plt.show()

# %%
sns.swarmplot(y,color='r')
sns.violinplot(y)
plt.show()

# %%
labels = [ "India", "Aus", "NZ", "PAK","AFG"]
freq = [ 260, 290, 220, 190, 60 ]
sns.barplot(x=labels,y=freq)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(12,4),facecolor="red")

x=np.random.randint(10,50,1000)
sns.countplot(x,ax=ax)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(12,4),facecolor="red")
sns.pointplot(x,y,ax=ax)
plt.show()

# %% [markdown]
# # Working on dataset tips

# %%
tip=sns.load_dataset("tips")   # this will load tips.csv online
print(type(tip))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tip.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tip.size
# Out:
# 1708

# %%
tip.shape
# Out:
# (244, 7)

# %%
tip.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tip['sex'].unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
tip['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
fig,ax=plt.subplots(figsize=(10,4),facecolor="gray")
x=tip['total_bill'][:25]
y=tip['tip'][:25]
plt.plot(x,y)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,4),facecolor="gray")
x=tip['total_bill'][:25]
y=tip['tip'][:25]
sns.lineplot(x,y,ax=ax)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,4),facecolor="gray")
x=tip['total_bill'][:25]
y=tip['tip'][:25]
sns.scatterplot(x,y,ax=ax)
plt.show()

# %%
x=tip['total_bill']
y=tip['tip']
sns.jointplot(x,y)
plt.show()

# %%
sns.distplot(y,kde=False,hist_kws={'edgecolor':"red"},bins=30,color="black")
plt.show()

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill',y='tip',data=tip)
plt.show()

# %%
sns.jointplot(x='size',y='total_bill',data=tip)
plt.show()

# %% [markdown]
# # to read file from a particular location
# # we use pd.read_csv("path")

# %%
tip=pd.read_csv("F:/Data_science/Seaborn-data/tips.csv")
print(type(tip))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.shape
# Out:
# (244, 7)

# %%
sns.countplot('size',data=tip,hue='sex')
plt.show()

# %%
sns.barplot("size","tip",data=tip)
plt.show()

# %%
sns.scatterplot('total_bill','tip',data=tip,hue="sex",size="smoker")
plt.show()

# %%
sns.violinplot(y='total_bill',x='sex',hue='smoker',data=tip)
sns.swarmplot(y='total_bill',x='sex',hue='smoker',data=tip)
plt.show()

# %%
sns.violinplot(split=True,y='total_bill',x='sex',hue='smoker',data=tip)
sns.swarmplot(y='total_bill',x='sex',hue='smoker',data=tip)
plt.show()

# %%
diamond = sns.load_dataset('diamonds')
#diamond = pd.read_csv("seaborn-data/diamonds.csv")

# %%
diamond.shape
# Out:
# (53940, 10)

# %%
diamond.size
# Out:
# 539400

# %%
diamond.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamond.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
plt.style.use('seaborn')

plt.hist(diamond['price'],bins=50,edgecolor='black')
plt.show()

# %%
sns.violinplot("price",data=diamond)
plt.show()

# %%
sns.scatterplot('carat','price',data=diamond)
plt.show()

# %%
sns.jointplot('carat','price',data=diamond)
plt.show()

# %%
d=diamond.sample(n=500)
d.shape
# Out:
# (500, 10)

# %%
sns.jointplot('carat','price',data=d)
plt.show()

# %%
sns.jointplot('carat','price',data=d,kind='kde')
plt.show()

# %%
sns.jointplot('carat','price',data=d,kind='reg')
plt.show()

# %% [markdown]
# ## RUG PLOT

# %%
sns.rugplot(d['price'])
plt.show()

# %%
 diamond.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
fig,ax = plt.subplots(figsize=(10,4))
sns.countplot(diamond['cut'],ax=ax)
height = []
for pat in ax.patches : 
    height.append(pat.get_height())
per = []
s = sum(height)
for h in height : 
    per.append(str(round(h/s,2)*100)+" %")
for pat,p in zip(ax.patches,per) : 
    height = pat.get_height()+1150
    width = pat.get_x()+0.2
    ax.text(width,height,p,fontsize=20)
plt.show()

# %%
matches=pd.read_csv("F:\\Data_science\seaborn-data\matches.csv")

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df=matches['player_of_match'][:25]
df
# Out:
# 0        Yuvraj Singh
# 1           SPD Smith
# 2             CA Lynn
# 3          GJ Maxwell
# 4           KM Jadhav
# 5         Rashid Khan
# 6              N Rana
# 7            AR Patel
# 8           SV Samson
# 9           JJ Bumrah
# 10          SP Narine
# 11         KA Pollard
# 12             AJ Tye
# 13         RV Uthappa
# 14        CJ Anderson
# 15             N Rana
# 16          BA Stokes
# 17    NM Coulter-Nile
# 18            B Kumar
# 19           CH Gayle
# 20      KS Williamson
# 21         JC Buttler
# 22           SK Raina
# 23     MJ McClenaghan
# 24           MS Dhoni
# Name: player_of_match, dtype: object

# %%
df=df.unique()
df
# Out:
# array(['Yuvraj Singh', 'SPD Smith', 'CA Lynn', 'GJ Maxwell', 'KM Jadhav',
#        'Rashid Khan', 'N Rana', 'AR Patel', 'SV Samson', 'JJ Bumrah',
#        'SP Narine', 'KA Pollard', 'AJ Tye', 'RV Uthappa', 'CJ Anderson',
#        'BA Stokes', 'NM Coulter-Nile', 'B Kumar', 'CH Gayle',
#        'KS Williamson', 'JC Buttler', 'SK Raina', 'MJ McClenaghan',
#        'MS Dhoni'], dtype=object)

# %%
s=matches['player_of_match'].value_counts()[:25]
s
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# SK Raina          14
# RG Sharma         14
# MS Dhoni          13
# G Gambhir         13
# MEK Hussey        12
# AM Rahane         12
# V Kohli           11
# V Sehwag          11
# DR Smith          11
# JH Kallis         10
# SR Watson         10
# KA Pollard         9
# SE Marsh           9
# A Mishra           9
# SR Tendulkar       8
# RV Uthappa         7
# RA Jadeja          7
# AC Gilchrist       7
# AT Rayudu          7
# AD Russell         6
# A Nehra            6
# Name: player_of_match, dtype: int64

# %%
name=list(s.index)
value=list(s.values)
name
# Out:
# ['CH Gayle',
#  'YK Pathan',
#  'DA Warner',
#  'AB de Villiers',
#  'SK Raina',
#  'RG Sharma',
#  'MS Dhoni',
#  'G Gambhir',
#  'MEK Hussey',
#  'AM Rahane',
#  'V Kohli',
#  'V Sehwag',
#  'DR Smith',
#  'JH Kallis',
#  'SR Watson',
#  'KA Pollard',
#  'SE Marsh',
#  'A Mishra',
#  'SR Tendulkar',
#  'RV Uthappa',
#  'RA Jadeja',
#  'AC Gilchrist',
#  'AT Rayudu',
#  'AD Russell',
#  'A Nehra']

# %%
value
# Out:
# [18,
#  16,
#  15,
#  15,
#  14,
#  14,
#  13,
#  13,
#  12,
#  12,
#  11,
#  11,
#  11,
#  10,
#  10,
#  9,
#  9,
#  9,
#  8,
#  7,
#  7,
#  7,
#  7,
#  6,
#  6]

# %%
fog,ax=plt.subplots(figsize=(10,4),facecolor='Gray')
sns.barplot(name,value,ax=ax)
plt.xticks(rotation=90)
plt.show()
